# %%
import numpy as np
import pandas as pd

# %%
all_data = pd.read_csv('states_counties.csv', encoding = "latin-1")
all_data
# Out:
#       SUMLEV  REGION  DIVISION  STATE  Unnamed: 4   STNAME      CTYNAME  \
# 0         50       3         6      1           1  Alabama     Autauga
# 1         50       3         6      1           3  Alabama     Baldwin
# 2         50       3         6      1           5  Alabama     Barbour
# 3         50       3         6      1           7  Alabama        Bibb
# 4         50       3         6      1           9  Alabama      Blount
# ...      ...     ...       ...    ...         ...      ...          ...
# 3138      50       4         8     56          37  Wyoming  Sweetwater
# 3139      50       4         8     56          39  Wyoming       Teton
# 3140      50       4         8     56          41  Wyoming       Uinta
# 3141      50       4         8     56          43  Wyoming    Washakie
# 3142      50       4         8     56          45  Wyoming      Weston
#
#       CENSUS2010POP
# 0             54571
# 1            182265
# 2             27457
# 3             22915
# ...

# %%
counties = all_data[all_data['STNAME'] == 'New Hampshire']
counties
#county_names[12][1].values[0][1:7]
# Out:
#       SUMLEV  REGION  DIVISION  STATE  Unnamed: 4         STNAME  \
# 1765      50       1         1     33           1  New Hampshire
# 1766      50       1         1     33           3  New Hampshire
# 1767      50       1         1     33           5  New Hampshire
# 1768      50       1         1     33           7  New Hampshire
# 1769      50       1         1     33           9  New Hampshire
# 1770      50       1         1     33          11  New Hampshire
# 1771      50       1         1     33          13  New Hampshire
# 1772      50       1         1     33          15  New Hampshire
# 1773      50       1         1     33          17  New Hampshire
# 1774      50       1         1     33          19  New Hampshire
#
#             CTYNAME  CENSUS2010POP
# 1765       Belknap           60088
# 1766       Carroll           47818
# 1767      Cheshire           77117
# 1768          Coos           33055
# 1769       Grafton           89118
# ...
